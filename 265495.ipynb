# %% [markdown]
# # Einführung in Maschinelles Lernen - Labor SS26

# %% [markdown]
# ### 1. Laden Sie die Trainingsdaten

# %%
import pandas as pd
data_train = pd.read_csv('data/project/train.csv', sep=';')
data_train['returnLabel'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ### 2. Führen Sie eine kurze EDA durch (Details auf Folie 13).

# %% [markdown]
# #### Histogramme erstellen

# %%
ax = data_train["customerType"].hist()

ax.set_title("Verteilung der Kundentypen")
ax.set_xlabel("Kundentyp")
ax.set_ylabel("Anzahl");

# %%
ax = data_train["totalAmount"].hist(bins=30)

ax.set_title("Verteilung von totalAmount")
ax.set_xlabel("totalAmount")
ax.set_ylabel("Anzahl");

# %%
ax = data_train["returnLabel"].hist()

ax.set_title("Histogramm von returnLabel")
ax.set_xlabel("returnLabel")
ax.set_ylabel("Anzahl");

# %%
axes = data_train.hist(
    column="returnLabel",
    by="customerType",
    bins=[-0.5, 0.5, 1.5],
    figsize=(8, 4)
)

for ax in axes.flatten():
    ax.set_xlabel("returnLabel")
    ax.set_ylabel("Anzahl")

# %% [markdown]
# ### 3. Füllen Sie fehlende Werte in den Trainingsdaten auf.

# %% [markdown]
# ### 4. Transformieren Sie die kategorischen Features mittels One-hot-encoding.

# %% [markdown]
# ### 5. Versuchen Sie auf Basis des Attributs basket Features zu bauen (z.B. wie oft kommt jede Kategorie im Basket vor).

# %% [markdown]
# ### 6. Skalieren Sie die Features mit einem StandardScaler.

# %% [markdown]
# ### 7. Trainieren Sie die folgenden Klassifikationsmodelle und probieren Sie die angegebenen Hyperparameter mittels Cross-Validation aus:
# 1. Logistische Regression: C :[0.1,1,4,5,6,10,30,100] und penalty: ["l1", "l2"]
# 2. Random Forest: n_estimators: [60,80,100,120,140] und max_depth: [2, 4, 6]
# 3. Gradient Boosting Tree: gleiche Hyperparameter wie bei Random Forest.

# %% [markdown]
# ### 8. Laden Sie die Testdaten.

# %% [markdown]
# ### 9. Entfernen Sie alle Zeilen mit fehlenden Werten.

# %% [markdown]
# ### 10. Transformieren Sie die Attribute genauso wie bei den Trainingsdaten.

# %% [markdown]
# ### 11. Skalieren Sie die Daten im gleichem Maß wie die Trainingsdaten.

# %% [markdown]
# ### 12. Machen Sie eine Vorhersage auf den Testdaten mit allen drei Modellen und den jeweils besten Hyperparametern aus der Cross Validation.

# %% [markdown]
# ### 13. Berechnen Sie für jedes der drei Modell Accuracy, Precision und Recall.

# %% [markdown]
# ### 14. Berechnen Sie außerdem die Accuracy auf den Trainingsdaten und vergleichen Sie Accuracy auf Trainings- und Testdaten. Liegt Overfitting vor? (Unterschied > 5%)

# %% [markdown]
# ### 15. Untersuchen Sie wieviele Datenpunkte es in den Testdaten gibt, welche von allen drei Modellen falsch klassifiziert wurden:
# 1. Bestimmen Sie für jedes der drei Modelle die Indizes der Testdatenpunkte auf
# welchen das jeweilige Modell falsch klassifiziert hat.
# 2. Nutzen Sie die set-Klasse in Python um die Anzahl an Datenpunkten zu
# bestimmen, welche von allen drei Modellen falsch klassifiziert wurden.

# %% [markdown]
# ### 16. Vergleichen Sie die Feature-Importances der drei Modelle in einem Plot.
